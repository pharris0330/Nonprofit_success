# %%
# Import the Pandas package
import pandas as pd

# Import the NumPy package
import numpy as np

# import fundamental plotting library in Python
import matplotlib.pyplot as plt

# Instruct jupyter to plot in the notebook
# %matplotlib inline

# %% [markdown]
# This is the pdf with all the Non profit info.
#
# https://www.irs.gov/pub/irs-soi/eo_info.pdf

# %%
df = pd.read_csv('https://raw.githubusercontent.com/pharris0330/team_31/main/eo_il.csv')

df.head()
# Out:
#         EIN                                              NAME  \
# 0   3390819                  REP RESOURCES EMPOWERING PARENTS
# 1  10438881            SHADY NOOK IMPROVEMENT ASSOCIATION INC
# 2  10482439                         MODERN WOODMEN OF AMERICA
# 3  10492125  ALLIANCE OF INDEPENDENT ACADEMIC MEDICAL CENTERS
# 4  10516987          ASSOCIATION OF PEDIATRIC ONCOLOGY NURSES
#
#                       ICO                       STREET         CITY STATE  \
# 0                     NaN                710 CR 1350 N     SULLIVAN    IL
# 1                     NaN                 629 W ELM ST      WHEATON    IL
# 2  % CHAPTER SERVICE DEPT                 1701 1ST AVE  ROCK ISLAND    IL
# 3   % F STEPHEN LARNED MD  401 N MICHIGAN AVE STE 1200      CHICAGO    IL
# 4         % DAVE BERGESON    8735 W HIGGINS RD STE 300      CHICAGO    IL
#
#           ZIP  GROUP  SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  \
# ...

# %%
chicago_filter = df["CITY"] == 'CHICAGO'

# %%
chicago = df[chicago_filter]

# %%
chicago_NTEE_CD = chicago['NTEE_CD']
chicago_NTEE_CD.value_counts()
